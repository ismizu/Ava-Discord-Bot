# %%
image = requests.get('http:'+data['current']['condition']['icon'])
img = Image.open(BytesIO(image.content))
img

# %%
import os
import discord
from discord.ext import commands
#from PIL import Image
#from io import BytesIO
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import requests
import json
#nest_asyncio only necessary for running in anaconda
    #allows running of loop necessary for server
import nest_asyncio
nest_asyncio.apply()

# %%
with open('.secrets/token.json') as f:
    token = json.load(f)

TOKEN = token['token']
bot = commands.Bot(command_prefix='!')

@bot.event
async def on_ready():
    print(f'{client.user} has connected.')

@bot.command()
async def test(ctx):
    await ctx.send('Hello!')

@bot.command()
async def weather(ctx, location = '07024'):
    #Retrieve API key
    with open('.secrets/APIs.json') as f:
        APIs = json.load(f)
    API_KEY = APIs['weather']
    #Format url with key, optional zipcode argument
    url = 'http://api.weatherapi.com/v1/forecast.json?key='+API_KEY+'&q='+location+'&days=3&aqi=no'
    response = requests.get(url)
    #Return response as json
    data = response.json()
    
    #Set json variables
    current_weather = data['current']
    daily_weather = data['forecast']['forecastday'][0]['day']
    
    #Instantiate variable for current UV index note
    uv_index_now = ''
    #Set UV index note
    if current_weather['uv'] < 3:
        uv_index_now = 'low'
    elif current_weather['uv'] in list(range(3,6)):
        uv_index_now = 'moderate'
    elif current_weather['uv'] in list(range(6,9)):
        uv_index_now = 'high'
    elif current_weather['uv'] in list(range(9,11)):
        uv_index_now = 'very high'
    else:
        uv_index_now = 'extremely high'

    #Duplicate above process for daily forecast
    uv_index_day = ''
    if daily_weather['uv'] < 3:
        uv_index_day = 'low'
    elif daily_weather['uv'] in list(range(3,6)):
        uv_index_day = 'moderate'
    elif daily_weather['uv'] in list(range(6,9)):
        uv_index_day = 'high'
    elif daily_weather['uv'] in list(range(9,11)):
        uv_index_day = 'very high'
    else:
        uv_index_day = 'extremely high'
    
    #Check for rain or snow
    weather_event = ''
    if daily_weather['daily_will_it_rain'] == 1 and daily_weather['daily_will_it_snow'] == 1:
        weather_event = 'Be careful today! Rain and Snow expected!'
    elif daily_weather['daily_will_it_rain'] == 1:
        weather_event = f"{daily_weather['daily_chance_of_rain']}% chance of rain"
    elif daily_weather['daily_will_it_snow'] == 1:
        weather_event = f"{daily_weather['daily_chance_of_snow']}% chance of snow"
    else:
        weather_event = 'No rain or snow expected today'
    
    #Send all weather data
    await ctx.send(f'''Here's today's forecast for {data['location']['name']}, {data['location']['region']}:
    
Right now it is {current_weather['condition']['text'].lower()} with:
    Temperature: {current_weather['temp_f']}F / {current_weather['temp_c']}C
    Feels like: {current_weather['feelslike_f']}F / {current_weather['feelslike_c']}C
    Humidity is: {current_weather['humidity']}%
    
    UV index is {uv_index_now} at: {current_weather['uv']}
    Cloud coverage is {current_weather['cloud']}%
    Wind Speed is {current_weather['wind_mph']}mph with {current_weather['gust_mph']}mph gusts
        
Overall, {daily_weather['condition']['text'].lower()} today with:
    {weather_event}
    High of: {daily_weather['maxtemp_f']}F / {daily_weather['maxtemp_c']}C
    Low of: {daily_weather['mintemp_f']}F / {daily_weather['mintemp_c']}C
    UV index is {uv_index_day} at: {daily_weather['uv']}
    Avg humidity will be: {daily_weather['avghumidity']}

Here is your hourly forecast:''')
    
    #Graph hourly weather data
    columns = ['time', 'temp_f', 'feelslike_f', 'chance_of_rain', 'chance_of_snow']
    hourly_forecast = pd.DataFrame(data['forecast']['forecastday'][0]['hour'])[columns]
    #Alter data to only display hour
    hourly_forecast['time'] = hourly_forecast['time'].map(lambda x: x[-5:-3])
    #Change percent chance of rain or snow from string to float
    hourly_forecast = hourly_forecast.astype({'chance_of_rain': np.float,
                                              'chance_of_snow': np.float})
    #Set seaborn theme and stacked graphs
    sns.set_theme()
    fig, ax = plt.subplots(figsize = (10,5))
    ax.plot(hourly_forecast['time'],
            hourly_forecast['temp_f']
           )
    ax.plot(hourly_forecast['time'],
            hourly_forecast['feelslike_f']
           )

    ax.plot(hourly_forecast['time'],
            hourly_forecast['chance_of_rain'],
            '--',
            color = 'c'
           )
    ax.plot(hourly_forecast['time'],
            hourly_forecast['chance_of_snow'],
            '-.',
            color = 'slategrey'
           )

    ax.set_yticks(list(range(0,100,10)))
    ax.legend(['Actual Temp', 'Feels Like', 'Chance of Rain', 'Chance of Snow'])
    plt.suptitle(f'Hourly Forecast for {data["forecast"]["forecastday"][0]["date"]}')
    #Save graph
    plt.savefig('plot.jpg')
    file = discord.File('plot.jpg')
    #Send graph
    await ctx.send(file = file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-ec16c504fba3> in <module>
# ----> 1 with open('.secrets/token.json') as f:
#       2     token = json.load(f)
#       3
#       4 TOKEN = token['token']
#       5 bot = commands.Bot(command_prefix='!')
#
# FileNotFoundError: [Errno 2] No such file or directory: '.secrets/token.json'

# %%
bot.run(TOKEN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-51bdbe786d33> in <module>
# ----> 1 bot.run(TOKEN)
#
# NameError: name 'bot' is not defined

# %%
data
# Out:
# {'location': {'name': 'Fort Lee',
#   'region': 'New Jersey',
#   'country': 'USA',
#   'lat': 40.85,
#   'lon': -73.98,
#   'tz_id': 'America/New_York',
#   'localtime_epoch': 1623364684,
#   'localtime': '2021-06-10 18:38'},
#  'current': {'temp_c': 24.4,
#   'temp_f': 75.9,
#   'condition': {'text': 'Sunny',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png'},
#   'wind_mph': 0.0,
#   'wind_kph': 0.0,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 37,
#   'cloud': 0,
#   'feelslike_c': 24.6,
#   'feelslike_f': 76.3,
#   'uv': 7.0,
#   'gust_mph': 12.5,
#   'gust_kph': 20.2},
#  'forecast': {'forecastday': [{'date': '2021-06-10',
#     'day': {'maxtemp_c': 28.5,
#      'maxtemp_f': 83.3,
#      'mintemp_c': 21.9,
#      'mintemp_f': 71.4,
#      'avgtemp_c': 24.8,
#      'avgtemp_f': 76.7,
#      'maxwind_kph': 21.2,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'avghumidity': 50.0,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': '0',
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': '0',
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#      'uv': 9.0},
#     'astro': {},
#     'hour': [{'time': '2021-06-10 00:00',
#       'temp_c': 24.8,
#       'temp_f': 76.6,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 59,
#       'feelslike_c': 27.0,
#       'feelslike_f': 80.6,
#       'windchill_c': 24.8,
#       'windchill_f': 76.6,
#       'heatindex_c': 27.0,
#       'heatindex_f': 80.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '41',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 9.4,
#       'gust_kph': 15.1,
#       'uv': 1.0},
#      {'time': '2021-06-10 01:00',
#       'temp_c': 24.2,
#       'temp_f': 75.6,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png'},
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 73,
#       'cloud': 42,
#       'feelslike_c': 26.1,
#       'feelslike_f': 79.0,
#       'windchill_c': 24.2,
#       'windchill_f': 75.6,
#       'heatindex_c': 26.1,
#       'heatindex_f': 79.0,
#       'will_it_rain': 0,
#       'chance_of_rain': '20',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.2,
#       'gust_kph': 18.0,
#       'uv': 1.0},
#      {'time': '2021-06-10 02:00',
#       'temp_c': 23.6,
#       'temp_f': 74.5,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 68,
#       'cloud': 25,
#       'feelslike_c': 25.3,
#       'feelslike_f': 77.5,
#       'windchill_c': 23.6,
#       'windchill_f': 74.5,
#       'heatindex_c': 25.3,
#       'heatindex_f': 77.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 12.8,
#       'gust_kph': 20.5,
#       'uv': 1.0},
#      {'time': '2021-06-10 03:00',
#       'temp_c': 23.3,
#       'temp_f': 73.9,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 72,
#       'cloud': 21,
#       'feelslike_c': 25.1,
#       'feelslike_f': 77.2,
#       'windchill_c': 23.3,
#       'windchill_f': 73.9,
#       'heatindex_c': 25.1,
#       'heatindex_f': 77.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.4,
#       'gust_kph': 18.4,
#       'uv': 1.0},
#      {'time': '2021-06-10 04:00',
#       'temp_c': 22.9,
#       'temp_f': 73.2,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 17,
#       'feelslike_c': 25.0,
#       'feelslike_f': 77.0,
#       'windchill_c': 22.9,
#       'windchill_f': 73.2,
#       'heatindex_c': 25.0,
#       'heatindex_f': 77.0,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 10.1,
#       'gust_kph': 16.2,
#       'uv': 1.0},
#      {'time': '2021-06-10 05:00',
#       'temp_c': 22.6,
#       'temp_f': 72.7,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 14,
#       'feelslike_c': 24.8,
#       'feelslike_f': 76.6,
#       'windchill_c': 22.6,
#       'windchill_f': 72.7,
#       'heatindex_c': 24.8,
#       'heatindex_f': 76.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 8.7,
#       'gust_kph': 14.0,
#       'uv': 1.0},
#      {'time': '2021-06-10 06:00',
#       'temp_c': 22.9,
#       'temp_f': 73.2,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 72,
#       'cloud': 25,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.8,
#       'windchill_c': 22.9,
#       'windchill_f': 73.2,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 9.8,
#       'gust_kph': 15.8,
#       'uv': 6.0},
#      {'time': '2021-06-10 07:00',
#       'temp_c': 23.3,
#       'temp_f': 73.9,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 65,
#       'cloud': 36,
#       'feelslike_c': 25.1,
#       'feelslike_f': 77.2,
#       'windchill_c': 23.3,
#       'windchill_f': 73.9,
#       'heatindex_c': 25.1,
#       'heatindex_f': 77.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 10.7,
#       'gust_kph': 17.3,
#       'uv': 6.0},
#      {'time': '2021-06-10 08:00',
#       'temp_c': 23.6,
#       'temp_f': 74.5,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 57,
#       'cloud': 47,
#       'feelslike_c': 25.2,
#       'feelslike_f': 77.4,
#       'windchill_c': 23.6,
#       'windchill_f': 74.5,
#       'heatindex_c': 25.2,
#       'heatindex_f': 77.4,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 6.0},
#      {'time': '2021-06-10 09:00',
#       'temp_c': 24.9,
#       'temp_f': 76.8,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 50,
#       'cloud': 42,
#       'feelslike_c': 25.9,
#       'feelslike_f': 78.6,
#       'windchill_c': 24.9,
#       'windchill_f': 76.8,
#       'heatindex_c': 25.9,
#       'heatindex_f': 78.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 6.0},
#      {'time': '2021-06-10 10:00',
#       'temp_c': 26.3,
#       'temp_f': 79.3,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 44,
#       'cloud': 37,
#       'feelslike_c': 26.5,
#       'feelslike_f': 79.7,
#       'windchill_c': 26.3,
#       'windchill_f': 79.3,
#       'heatindex_c': 26.5,
#       'heatindex_f': 79.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.6,
#       'gust_kph': 18.7,
#       'uv': 7.0},
#      {'time': '2021-06-10 11:00',
#       'temp_c': 27.6,
#       'temp_f': 81.7,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 37,
#       'cloud': 32,
#       'feelslike_c': 27.2,
#       'feelslike_f': 81.0,
#       'windchill_c': 27.6,
#       'windchill_f': 81.7,
#       'heatindex_c': 27.2,
#       'heatindex_f': 81.0,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.6,
#       'gust_kph': 18.7,
#       'uv': 7.0},
#      {'time': '2021-06-10 12:00',
#       'temp_c': 28.0,
#       'temp_f': 82.4,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 35,
#       'cloud': 29,
#       'feelslike_c': 27.4,
#       'feelslike_f': 81.3,
#       'windchill_c': 28.0,
#       'windchill_f': 82.4,
#       'heatindex_c': 27.4,
#       'heatindex_f': 81.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.4,
#       'gust_kph': 18.4,
#       'uv': 7.0},
#      {'time': '2021-06-10 13:00',
#       'temp_c': 28.3,
#       'temp_f': 82.9,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 33,
#       'cloud': 27,
#       'feelslike_c': 27.5,
#       'feelslike_f': 81.5,
#       'windchill_c': 28.3,
#       'windchill_f': 82.9,
#       'heatindex_c': 27.5,
#       'heatindex_f': 81.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.4,
#       'gust_kph': 18.4,
#       'uv': 7.0},
#      {'time': '2021-06-10 14:00',
#       'temp_c': 28.7,
#       'temp_f': 83.7,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 31,
#       'cloud': 24,
#       'feelslike_c': 27.7,
#       'feelslike_f': 81.9,
#       'windchill_c': 28.7,
#       'windchill_f': 83.7,
#       'heatindex_c': 27.7,
#       'heatindex_f': 81.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.2,
#       'gust_kph': 18.0,
#       'uv': 7.0},
#      {'time': '2021-06-10 15:00',
#       'temp_c': 28.2,
#       'temp_f': 82.8,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 32,
#       'cloud': 18,
#       'feelslike_c': 27.3,
#       'feelslike_f': 81.1,
#       'windchill_c': 28.2,
#       'windchill_f': 82.8,
#       'heatindex_c': 27.3,
#       'heatindex_f': 81.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 12.3,
#       'gust_kph': 19.8,
#       'uv': 7.0},
#      {'time': '2021-06-10 16:00',
#       'temp_c': 27.6,
#       'temp_f': 81.7,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 32,
#       'cloud': 13,
#       'feelslike_c': 26.8,
#       'feelslike_f': 80.2,
#       'windchill_c': 27.6,
#       'windchill_f': 81.7,
#       'heatindex_c': 26.8,
#       'heatindex_f': 80.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 13.6,
#       'gust_kph': 22.0,
#       'uv': 7.0},
#      {'time': '2021-06-10 17:00',
#       'temp_c': 27.1,
#       'temp_f': 80.8,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 32,
#       'cloud': 7,
#       'feelslike_c': 26.4,
#       'feelslike_f': 79.5,
#       'windchill_c': 27.1,
#       'windchill_f': 80.8,
#       'heatindex_c': 26.4,
#       'heatindex_f': 79.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 14.8,
#       'gust_kph': 23.8,
#       'uv': 7.0},
#      {'time': '2021-06-10 18:00',
#       'temp_c': 26.1,
#       'temp_f': 79.0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 35,
#       'cloud': 7,
#       'feelslike_c': 27.0,
#       'feelslike_f': 80.6,
#       'windchill_c': 26.1,
#       'windchill_f': 79.0,
#       'heatindex_c': 27.0,
#       'heatindex_f': 80.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 15.4,
#       'gust_kph': 24.8,
#       'uv': 7.0},
#      {'time': '2021-06-10 19:00',
#       'temp_c': 25.1,
#       'temp_f': 77.2,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 38,
#       'cloud': 7,
#       'feelslike_c': 27.5,
#       'feelslike_f': 81.5,
#       'windchill_c': 25.1,
#       'windchill_f': 77.2,
#       'heatindex_c': 27.5,
#       'heatindex_f': 81.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 16.1,
#       'gust_kph': 25.9,
#       'uv': 7.0},
#      {'time': '2021-06-10 20:00',
#       'temp_c': 24.1,
#       'temp_f': 75.4,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 41,
#       'cloud': 7,
#       'feelslike_c': 28.1,
#       'feelslike_f': 82.6,
#       'windchill_c': 24.1,
#       'windchill_f': 75.4,
#       'heatindex_c': 28.1,
#       'heatindex_f': 82.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 16.8,
#       'gust_kph': 27.0,
#       'uv': 6.0},
#      {'time': '2021-06-10 21:00',
#       'temp_c': 23.1,
#       'temp_f': 73.6,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 44,
#       'cloud': 6,
#       'feelslike_c': 27.1,
#       'feelslike_f': 80.8,
#       'windchill_c': 23.1,
#       'windchill_f': 73.6,
#       'heatindex_c': 27.1,
#       'heatindex_f': 80.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 15.2,
#       'gust_kph': 24.5,
#       'uv': 1.0},
#      {'time': '2021-06-10 22:00',
#       'temp_c': 22.1,
#       'temp_f': 71.8,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 47,
#       'cloud': 4,
#       'feelslike_c': 26.1,
#       'feelslike_f': 79.0,
#       'windchill_c': 22.1,
#       'windchill_f': 71.8,
#       'heatindex_c': 26.1,
#       'heatindex_f': 79.0,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 13.9,
#       'gust_kph': 22.3,
#       'uv': 1.0},
#      {'time': '2021-06-10 23:00',
#       'temp_c': 21.1,
#       'temp_f': 70.0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 50,
#       'cloud': 3,
#       'feelslike_c': 21.1,
#       'feelslike_f': 70.0,
#       'windchill_c': 21.1,
#       'windchill_f': 70.0,
#       'heatindex_c': 25.1,
#       'heatindex_f': 77.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 12.3,
#       'gust_kph': 19.8,
#       'uv': 1.0}]},
#    {'date': '2021-06-11',
#     'day': {'maxtemp_c': 21.1,
#      'maxtemp_f': 70.0,
#      'mintemp_c': 17.1,
#      'mintemp_f': 62.8,
#      'avgtemp_c': 19.1,
#      'avgtemp_f': 66.4,
#      'maxwind_kph': 14.4,
#      'totalprecip_mm': 0.1,
#      'totalprecip_in': 0.0,
#      'avghumidity': 61.0,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': '0',
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': '0',
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#      'uv': 7.0},
#     'astro': {},
#     'hour': [{'time': '2021-06-11 00:00',
#       'temp_c': 19.9,
#       'temp_f': 67.8,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 52,
#       'cloud': 4,
#       'feelslike_c': 19.9,
#       'feelslike_f': 67.8,
#       'windchill_c': 19.9,
#       'windchill_f': 67.8,
#       'heatindex_c': 22.6,
#       'heatindex_f': 72.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 12.1,
#       'gust_kph': 19.4,
#       'uv': 1.0},
#      {'time': '2021-06-11 01:00',
#       'temp_c': 18.8,
#       'temp_f': 65.8,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 55,
#       'cloud': 5,
#       'feelslike_c': 18.8,
#       'feelslike_f': 65.8,
#       'windchill_c': 18.8,
#       'windchill_f': 65.8,
#       'heatindex_c': 20.1,
#       'heatindex_f': 68.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 1.0},
#      {'time': '2021-06-11 02:00',
#       'temp_c': 17.6,
#       'temp_f': 63.7,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 57,
#       'cloud': 6,
#       'feelslike_c': 17.6,
#       'feelslike_f': 63.7,
#       'windchill_c': 17.6,
#       'windchill_f': 63.7,
#       'heatindex_c': 17.6,
#       'heatindex_f': 63.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.6,
#       'gust_kph': 18.7,
#       'uv': 1.0},
#      {'time': '2021-06-11 03:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 57,
#       'cloud': 7,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.4,
#       'gust_kph': 18.4,
#       'uv': 1.0},
#      {'time': '2021-06-11 04:00',
#       'temp_c': 17.1,
#       'temp_f': 62.8,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 57,
#       'cloud': 9,
#       'feelslike_c': 17.1,
#       'feelslike_f': 62.8,
#       'windchill_c': 17.1,
#       'windchill_f': 62.8,
#       'heatindex_c': 17.1,
#       'heatindex_f': 62.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.2,
#       'gust_kph': 18.0,
#       'uv': 1.0},
#      {'time': '2021-06-11 05:00',
#       'temp_c': 16.9,
#       'temp_f': 62.4,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 57,
#       'cloud': 11,
#       'feelslike_c': 16.9,
#       'feelslike_f': 62.4,
#       'windchill_c': 16.9,
#       'windchill_f': 62.4,
#       'heatindex_c': 16.9,
#       'heatindex_f': 62.4,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.0,
#       'gust_kph': 17.6,
#       'uv': 1.0},
#      {'time': '2021-06-11 06:00',
#       'temp_c': 17.1,
#       'temp_f': 62.8,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 55,
#       'cloud': 15,
#       'feelslike_c': 17.1,
#       'feelslike_f': 62.8,
#       'windchill_c': 17.1,
#       'windchill_f': 62.8,
#       'heatindex_c': 17.1,
#       'heatindex_f': 62.8,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 10.7,
#       'gust_kph': 17.3,
#       'uv': 5.0},
#      {'time': '2021-06-11 07:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 52,
#       'cloud': 20,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 10.5,
#       'gust_kph': 16.9,
#       'uv': 5.0},
#      {'time': '2021-06-11 08:00',
#       'temp_c': 17.6,
#       'temp_f': 63.7,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 50,
#       'cloud': 24,
#       'feelslike_c': 17.6,
#       'feelslike_f': 63.7,
#       'windchill_c': 17.6,
#       'windchill_f': 63.7,
#       'heatindex_c': 17.6,
#       'heatindex_f': 63.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 10.3,
#       'gust_kph': 16.6,
#       'uv': 5.0},
#      {'time': '2021-06-11 09:00',
#       'temp_c': 18.8,
#       'temp_f': 65.8,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 45,
#       'cloud': 31,
#       'feelslike_c': 18.8,
#       'feelslike_f': 65.8,
#       'windchill_c': 18.8,
#       'windchill_f': 65.8,
#       'heatindex_c': 19.6,
#       'heatindex_f': 67.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 10.5,
#       'gust_kph': 16.9,
#       'uv': 5.0},
#      {'time': '2021-06-11 10:00',
#       'temp_c': 20.0,
#       'temp_f': 68.0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 41,
#       'cloud': 38,
#       'feelslike_c': 20.0,
#       'feelslike_f': 68.0,
#       'windchill_c': 20.0,
#       'windchill_f': 68.0,
#       'heatindex_c': 21.6,
#       'heatindex_f': 70.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 10.5,
#       'gust_kph': 16.9,
#       'uv': 6.0},
#      {'time': '2021-06-11 11:00',
#       'temp_c': 21.2,
#       'temp_f': 70.2,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 36,
#       'cloud': 46,
#       'feelslike_c': 21.2,
#       'feelslike_f': 70.2,
#       'windchill_c': 21.2,
#       'windchill_f': 70.2,
#       'heatindex_c': 23.6,
#       'heatindex_f': 74.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 10.7,
#       'gust_kph': 17.3,
#       'uv': 6.0},
#      {'time': '2021-06-11 12:00',
#       'temp_c': 21.2,
#       'temp_f': 70.2,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 38,
#       'cloud': 57,
#       'feelslike_c': 21.2,
#       'feelslike_f': 70.2,
#       'windchill_c': 21.2,
#       'windchill_f': 70.2,
#       'heatindex_c': 23.7,
#       'heatindex_f': 74.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.2,
#       'gust_kph': 18.0,
#       'uv': 5.0},
#      {'time': '2021-06-11 13:00',
#       'temp_c': 21.3,
#       'temp_f': 70.3,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 40,
#       'cloud': 68,
#       'feelslike_c': 21.3,
#       'feelslike_f': 70.3,
#       'windchill_c': 21.3,
#       'windchill_f': 70.3,
#       'heatindex_c': 23.9,
#       'heatindex_f': 75.0,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 6.0},
#      {'time': '2021-06-11 14:00',
#       'temp_c': 21.3,
#       'temp_f': 70.3,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 42,
#       'cloud': 79,
#       'feelslike_c': 21.3,
#       'feelslike_f': 70.3,
#       'windchill_c': 21.3,
#       'windchill_f': 70.3,
#       'heatindex_c': 24.0,
#       'heatindex_f': 75.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 12.3,
#       'gust_kph': 19.8,
#       'uv': 5.0},
#      {'time': '2021-06-11 15:00',
#       'temp_c': 21.0,
#       'temp_f': 69.8,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 46,
#       'cloud': 86,
#       'feelslike_c': 21.0,
#       'feelslike_f': 69.8,
#       'windchill_c': 21.0,
#       'windchill_f': 69.8,
#       'heatindex_c': 22.8,
#       'heatindex_f': 73.0,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 12.1,
#       'gust_kph': 19.4,
#       'uv': 5.0},
#      {'time': '2021-06-11 16:00',
#       'temp_c': 20.6,
#       'temp_f': 69.1,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 51,
#       'cloud': 93,
#       'feelslike_c': 20.6,
#       'feelslike_f': 69.1,
#       'windchill_c': 20.6,
#       'windchill_f': 69.1,
#       'heatindex_c': 21.5,
#       'heatindex_f': 70.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.6,
#       'gust_kph': 18.7,
#       'uv': 5.0},
#      {'time': '2021-06-11 17:00',
#       'temp_c': 20.3,
#       'temp_f': 68.5,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 56,
#       'cloud': 100,
#       'feelslike_c': 20.3,
#       'feelslike_f': 68.5,
#       'windchill_c': 20.3,
#       'windchill_f': 68.5,
#       'heatindex_c': 20.3,
#       'heatindex_f': 68.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.4,
#       'gust_kph': 18.4,
#       'uv': 5.0},
#      {'time': '2021-06-11 18:00',
#       'temp_c': 20.0,
#       'temp_f': 68.0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 59,
#       'cloud': 100,
#       'feelslike_c': 20.0,
#       'feelslike_f': 68.0,
#       'windchill_c': 20.0,
#       'windchill_f': 68.0,
#       'heatindex_c': 20.0,
#       'heatindex_f': 68.0,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 11.2,
#       'gust_kph': 18.0,
#       'uv': 5.0},
#      {'time': '2021-06-11 19:00',
#       'temp_c': 19.8,
#       'temp_f': 67.6,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 62,
#       'cloud': 100,
#       'feelslike_c': 19.8,
#       'feelslike_f': 67.6,
#       'windchill_c': 19.8,
#       'windchill_f': 67.6,
#       'heatindex_c': 19.8,
#       'heatindex_f': 67.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 10.7,
#       'gust_kph': 17.3,
#       'uv': 4.0},
#      {'time': '2021-06-11 20:00',
#       'temp_c': 19.5,
#       'temp_f': 67.1,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 65,
#       'cloud': 100,
#       'feelslike_c': 19.5,
#       'feelslike_f': 67.1,
#       'windchill_c': 19.5,
#       'windchill_f': 67.1,
#       'heatindex_c': 19.5,
#       'heatindex_f': 67.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 10.5,
#       'gust_kph': 16.9,
#       'uv': 4.0},
#      {'time': '2021-06-11 21:00',
#       'temp_c': 19.3,
#       'temp_f': 66.7,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 67,
#       'cloud': 100,
#       'feelslike_c': 19.3,
#       'feelslike_f': 66.7,
#       'windchill_c': 19.3,
#       'windchill_f': 66.7,
#       'heatindex_c': 19.3,
#       'heatindex_f': 66.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 10.1,
#       'gust_kph': 16.2,
#       'uv': 1.0},
#      {'time': '2021-06-11 22:00',
#       'temp_c': 19.2,
#       'temp_f': 66.6,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 69,
#       'cloud': 99,
#       'feelslike_c': 19.2,
#       'feelslike_f': 66.6,
#       'windchill_c': 19.2,
#       'windchill_f': 66.6,
#       'heatindex_c': 19.2,
#       'heatindex_f': 66.6,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 9.8,
#       'gust_kph': 15.8,
#       'uv': 1.0},
#      {'time': '2021-06-11 23:00',
#       'temp_c': 19.0,
#       'temp_f': 66.2,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 71,
#       'cloud': 99,
#       'feelslike_c': 19.0,
#       'feelslike_f': 66.2,
#       'windchill_c': 19.0,
#       'windchill_f': 66.2,
#       'heatindex_c': 19.0,
#       'heatindex_f': 66.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 9.4,
#       'gust_kph': 15.1,
#       'uv': 1.0}]},
#    {'date': '2021-06-12',
#     'day': {'maxtemp_c': 24.9,
#      'maxtemp_f': 76.8,
#      'mintemp_c': 17.7,
#      'mintemp_f': 63.9,
#      'avgtemp_c': 20.0,
#      'avgtemp_f': 67.9,
#      'maxwind_kph': 13.0,
#      'totalprecip_mm': 0.1,
#      'totalprecip_in': 0.0,
#      'avghumidity': 72.0,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': '0',
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': '0',
#      'condition': {'text': 'Overcast',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#      'uv': 8.0},
#     'astro': {},
#     'hour': [{'time': '2021-06-12 00:00',
#       'temp_c': 18.9,
#       'temp_f': 66.0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 72,
#       'cloud': 99,
#       'feelslike_c': 18.9,
#       'feelslike_f': 66.0,
#       'windchill_c': 18.9,
#       'windchill_f': 66.0,
#       'heatindex_c': 18.9,
#       'heatindex_f': 66.0,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 8.9,
#       'gust_kph': 14.4,
#       'uv': 1.0},
#      {'time': '2021-06-12 01:00',
#       'temp_c': 18.7,
#       'temp_f': 65.7,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 73,
#       'cloud': 100,
#       'feelslike_c': 18.7,
#       'feelslike_f': 65.7,
#       'windchill_c': 18.7,
#       'windchill_f': 65.7,
#       'heatindex_c': 18.7,
#       'heatindex_f': 65.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 8.3,
#       'gust_kph': 13.3,
#       'uv': 1.0},
#      {'time': '2021-06-12 02:00',
#       'temp_c': 18.6,
#       'temp_f': 65.5,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 74,
#       'cloud': 100,
#       'feelslike_c': 18.6,
#       'feelslike_f': 65.5,
#       'windchill_c': 18.6,
#       'windchill_f': 65.5,
#       'heatindex_c': 18.6,
#       'heatindex_f': 65.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 7.8,
#       'gust_kph': 12.6,
#       'uv': 1.0},
#      {'time': '2021-06-12 03:00',
#       'temp_c': 18.5,
#       'temp_f': 65.3,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 100,
#       'feelslike_c': 18.5,
#       'feelslike_f': 65.3,
#       'windchill_c': 18.5,
#       'windchill_f': 65.3,
#       'heatindex_c': 18.5,
#       'heatindex_f': 65.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 6.5,
#       'gust_kph': 10.4,
#       'uv': 1.0},
#      {'time': '2021-06-12 04:00',
#       'temp_c': 18.4,
#       'temp_f': 65.1,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 100,
#       'feelslike_c': 18.4,
#       'feelslike_f': 65.1,
#       'windchill_c': 18.4,
#       'windchill_f': 65.1,
#       'heatindex_c': 18.4,
#       'heatindex_f': 65.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 5.4,
#       'gust_kph': 8.6,
#       'uv': 1.0},
#      {'time': '2021-06-12 05:00',
#       'temp_c': 18.3,
#       'temp_f': 64.9,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 100,
#       'feelslike_c': 18.3,
#       'feelslike_f': 64.9,
#       'windchill_c': 18.3,
#       'windchill_f': 64.9,
#       'heatindex_c': 18.3,
#       'heatindex_f': 64.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 4.0,
#       'gust_kph': 6.5,
#       'uv': 1.0},
#      {'time': '2021-06-12 06:00',
#       'temp_c': 18.7,
#       'temp_f': 65.7,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 90,
#       'feelslike_c': 18.7,
#       'feelslike_f': 65.7,
#       'windchill_c': 18.7,
#       'windchill_f': 65.7,
#       'heatindex_c': 18.7,
#       'heatindex_f': 65.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 3.8,
#       'gust_kph': 6.1,
#       'uv': 4.0},
#      {'time': '2021-06-12 07:00',
#       'temp_c': 19.0,
#       'temp_f': 66.2,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 74,
#       'cloud': 80,
#       'feelslike_c': 19.0,
#       'feelslike_f': 66.2,
#       'windchill_c': 19.0,
#       'windchill_f': 66.2,
#       'heatindex_c': 19.0,
#       'heatindex_f': 66.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 3.6,
#       'gust_kph': 5.8,
#       'uv': 4.0},
#      {'time': '2021-06-12 08:00',
#       'temp_c': 19.4,
#       'temp_f': 66.9,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 73,
#       'cloud': 69,
#       'feelslike_c': 19.4,
#       'feelslike_f': 66.9,
#       'windchill_c': 19.4,
#       'windchill_f': 66.9,
#       'heatindex_c': 19.4,
#       'heatindex_f': 66.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 3.4,
#       'gust_kph': 5.4,
#       'uv': 4.0},
#      {'time': '2021-06-12 09:00',
#       'temp_c': 20.1,
#       'temp_f': 68.2,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 70,
#       'cloud': 80,
#       'feelslike_c': 20.1,
#       'feelslike_f': 68.2,
#       'windchill_c': 20.1,
#       'windchill_f': 68.2,
#       'heatindex_c': 21.1,
#       'heatindex_f': 70.0,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 4.5,
#       'gust_kph': 7.2,
#       'uv': 5.0},
#      {'time': '2021-06-12 10:00',
#       'temp_c': 20.8,
#       'temp_f': 69.4,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 67,
#       'cloud': 90,
#       'feelslike_c': 20.8,
#       'feelslike_f': 69.4,
#       'windchill_c': 20.8,
#       'windchill_f': 69.4,
#       'heatindex_c': 22.8,
#       'heatindex_f': 73.0,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 5.4,
#       'gust_kph': 8.6,
#       'uv': 5.0},
#      {'time': '2021-06-12 11:00',
#       'temp_c': 21.5,
#       'temp_f': 70.7,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 65,
#       'cloud': 100,
#       'feelslike_c': 21.5,
#       'feelslike_f': 70.7,
#       'windchill_c': 21.5,
#       'windchill_f': 70.7,
#       'heatindex_c': 24.5,
#       'heatindex_f': 76.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 6.5,
#       'gust_kph': 10.4,
#       'uv': 5.0},
#      {'time': '2021-06-12 12:00',
#       'temp_c': 21.8,
#       'temp_f': 71.2,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 64,
#       'cloud': 98,
#       'feelslike_c': 21.8,
#       'feelslike_f': 71.2,
#       'windchill_c': 21.8,
#       'windchill_f': 71.2,
#       'heatindex_c': 24.6,
#       'heatindex_f': 76.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 6.7,
#       'gust_kph': 10.8,
#       'uv': 5.0},
#      {'time': '2021-06-12 13:00',
#       'temp_c': 22.2,
#       'temp_f': 72.0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 63,
#       'cloud': 97,
#       'feelslike_c': 24.6,
#       'feelslike_f': 76.3,
#       'windchill_c': 22.2,
#       'windchill_f': 72.0,
#       'heatindex_c': 24.6,
#       'heatindex_f': 76.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 6.9,
#       'gust_kph': 11.2,
#       'uv': 5.0},
#      {'time': '2021-06-12 14:00',
#       'temp_c': 22.5,
#       'temp_f': 72.5,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 62,
#       'cloud': 95,
#       'feelslike_c': 24.7,
#       'feelslike_f': 76.5,
#       'windchill_c': 22.5,
#       'windchill_f': 72.5,
#       'heatindex_c': 24.7,
#       'heatindex_f': 76.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 7.2,
#       'gust_kph': 11.5,
#       'uv': 5.0},
#      {'time': '2021-06-12 15:00',
#       'temp_c': 22.0,
#       'temp_f': 71.6,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 63,
#       'cloud': 90,
#       'feelslike_c': 24.6,
#       'feelslike_f': 76.3,
#       'windchill_c': 22.0,
#       'windchill_f': 71.6,
#       'heatindex_c': 24.6,
#       'heatindex_f': 76.3,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 7.4,
#       'gust_kph': 11.9,
#       'uv': 5.0},
#      {'time': '2021-06-12 16:00',
#       'temp_c': 21.6,
#       'temp_f': 70.9,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 65,
#       'cloud': 85,
#       'feelslike_c': 21.6,
#       'feelslike_f': 70.9,
#       'windchill_c': 21.6,
#       'windchill_f': 70.9,
#       'heatindex_c': 24.5,
#       'heatindex_f': 76.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 7.8,
#       'gust_kph': 12.6,
#       'uv': 5.0},
#      {'time': '2021-06-12 17:00',
#       'temp_c': 21.1,
#       'temp_f': 70.0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 67,
#       'cloud': 80,
#       'feelslike_c': 21.1,
#       'feelslike_f': 70.0,
#       'windchill_c': 21.1,
#       'windchill_f': 70.0,
#       'heatindex_c': 24.4,
#       'heatindex_f': 75.9,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 8.1,
#       'gust_kph': 13.0,
#       'uv': 5.0},
#      {'time': '2021-06-12 18:00',
#       'temp_c': 20.7,
#       'temp_f': 69.3,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 68,
#       'cloud': 64,
#       'feelslike_c': 20.7,
#       'feelslike_f': 69.3,
#       'windchill_c': 20.7,
#       'windchill_f': 69.3,
#       'heatindex_c': 22.9,
#       'heatindex_f': 73.2,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 7.8,
#       'gust_kph': 12.6,
#       'uv': 6.0},
#      {'time': '2021-06-12 19:00',
#       'temp_c': 20.4,
#       'temp_f': 68.7,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 70,
#       'cloud': 49,
#       'feelslike_c': 20.4,
#       'feelslike_f': 68.7,
#       'windchill_c': 20.4,
#       'windchill_f': 68.7,
#       'heatindex_c': 21.5,
#       'heatindex_f': 70.7,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 7.4,
#       'gust_kph': 11.9,
#       'uv': 5.0},
#      {'time': '2021-06-12 20:00',
#       'temp_c': 20.0,
#       'temp_f': 68.0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 71,
#       'cloud': 33,
#       'feelslike_c': 20.0,
#       'feelslike_f': 68.0,
#       'windchill_c': 20.0,
#       'windchill_f': 68.0,
#       'heatindex_c': 20.0,
#       'heatindex_f': 68.0,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 7.2,
#       'gust_kph': 11.5,
#       'uv': 6.0},
#      {'time': '2021-06-12 21:00',
#       'temp_c': 19.5,
#       'temp_f': 67.1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 73,
#       'cloud': 31,
#       'feelslike_c': 19.5,
#       'feelslike_f': 67.1,
#       'windchill_c': 19.5,
#       'windchill_f': 67.1,
#       'heatindex_c': 19.5,
#       'heatindex_f': 67.1,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 7.4,
#       'gust_kph': 11.9,
#       'uv': 1.0},
#      {'time': '2021-06-12 22:00',
#       'temp_c': 19.1,
#       'temp_f': 66.4,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 30,
#       'feelslike_c': 19.1,
#       'feelslike_f': 66.4,
#       'windchill_c': 19.1,
#       'windchill_f': 66.4,
#       'heatindex_c': 19.1,
#       'heatindex_f': 66.4,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 7.6,
#       'gust_kph': 12.2,
#       'uv': 1.0},
#      {'time': '2021-06-12 23:00',
#       'temp_c': 18.6,
#       'temp_f': 65.5,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 28,
#       'feelslike_c': 18.6,
#       'feelslike_f': 65.5,
#       'windchill_c': 18.6,
#       'windchill_f': 65.5,
#       'heatindex_c': 18.6,
#       'heatindex_f': 65.5,
#       'will_it_rain': 0,
#       'chance_of_rain': '0',
#       'will_it_snow': 0,
#       'chance_of_snow': '0',
#       'gust_mph': 7.8,
#       'gust_kph': 12.6,
#       'uv': 1.0}]}]}}

# %%
data['forecast']['forecastday']
# Out:
# [{'date': '2021-06-10',
#   'day': {'maxtemp_c': 28.5,
#    'maxtemp_f': 83.3,
#    'mintemp_c': 21.9,
#    'mintemp_f': 71.4,
#    'avgtemp_c': 24.8,
#    'avgtemp_f': 76.7,
#    'maxwind_kph': 21.2,
#    'totalprecip_mm': 0.0,
#    'totalprecip_in': 0.0,
#    'avghumidity': 50.0,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': '0',
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': '0',
#    'condition': {'text': 'Partly cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#    'uv': 9.0},
#   'astro': {},
#   'hour': [{'time': '2021-06-10 00:00',
#     'temp_c': 24.8,
#     'temp_f': 76.6,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.1,
#     'precip_in': 0.0,
#     'humidity': 77,
#     'cloud': 59,
#     'feelslike_c': 27.0,
#     'feelslike_f': 80.6,
#     'windchill_c': 24.8,
#     'windchill_f': 76.6,
#     'heatindex_c': 27.0,
#     'heatindex_f': 80.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '41',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 1.0},
#    {'time': '2021-06-10 01:00',
#     'temp_c': 24.2,
#     'temp_f': 75.6,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png'},
#     'precip_mm': 0.1,
#     'precip_in': 0.0,
#     'humidity': 73,
#     'cloud': 42,
#     'feelslike_c': 26.1,
#     'feelslike_f': 79.0,
#     'windchill_c': 24.2,
#     'windchill_f': 75.6,
#     'heatindex_c': 26.1,
#     'heatindex_f': 79.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '20',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.2,
#     'gust_kph': 18.0,
#     'uv': 1.0},
#    {'time': '2021-06-10 02:00',
#     'temp_c': 23.6,
#     'temp_f': 74.5,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 68,
#     'cloud': 25,
#     'feelslike_c': 25.3,
#     'feelslike_f': 77.5,
#     'windchill_c': 23.6,
#     'windchill_f': 74.5,
#     'heatindex_c': 25.3,
#     'heatindex_f': 77.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 12.8,
#     'gust_kph': 20.5,
#     'uv': 1.0},
#    {'time': '2021-06-10 03:00',
#     'temp_c': 23.3,
#     'temp_f': 73.9,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 72,
#     'cloud': 21,
#     'feelslike_c': 25.1,
#     'feelslike_f': 77.2,
#     'windchill_c': 23.3,
#     'windchill_f': 73.9,
#     'heatindex_c': 25.1,
#     'heatindex_f': 77.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.4,
#     'gust_kph': 18.4,
#     'uv': 1.0},
#    {'time': '2021-06-10 04:00',
#     'temp_c': 22.9,
#     'temp_f': 73.2,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 76,
#     'cloud': 17,
#     'feelslike_c': 25.0,
#     'feelslike_f': 77.0,
#     'windchill_c': 22.9,
#     'windchill_f': 73.2,
#     'heatindex_c': 25.0,
#     'heatindex_f': 77.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 10.1,
#     'gust_kph': 16.2,
#     'uv': 1.0},
#    {'time': '2021-06-10 05:00',
#     'temp_c': 22.6,
#     'temp_f': 72.7,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 80,
#     'cloud': 14,
#     'feelslike_c': 24.8,
#     'feelslike_f': 76.6,
#     'windchill_c': 22.6,
#     'windchill_f': 72.7,
#     'heatindex_c': 24.8,
#     'heatindex_f': 76.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 8.7,
#     'gust_kph': 14.0,
#     'uv': 1.0},
#    {'time': '2021-06-10 06:00',
#     'temp_c': 22.9,
#     'temp_f': 73.2,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 72,
#     'cloud': 25,
#     'feelslike_c': 24.9,
#     'feelslike_f': 76.8,
#     'windchill_c': 22.9,
#     'windchill_f': 73.2,
#     'heatindex_c': 24.9,
#     'heatindex_f': 76.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 9.8,
#     'gust_kph': 15.8,
#     'uv': 6.0},
#    {'time': '2021-06-10 07:00',
#     'temp_c': 23.3,
#     'temp_f': 73.9,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 65,
#     'cloud': 36,
#     'feelslike_c': 25.1,
#     'feelslike_f': 77.2,
#     'windchill_c': 23.3,
#     'windchill_f': 73.9,
#     'heatindex_c': 25.1,
#     'heatindex_f': 77.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 10.7,
#     'gust_kph': 17.3,
#     'uv': 6.0},
#    {'time': '2021-06-10 08:00',
#     'temp_c': 23.6,
#     'temp_f': 74.5,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 57,
#     'cloud': 47,
#     'feelslike_c': 25.2,
#     'feelslike_f': 77.4,
#     'windchill_c': 23.6,
#     'windchill_f': 74.5,
#     'heatindex_c': 25.2,
#     'heatindex_f': 77.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.9,
#     'gust_kph': 19.1,
#     'uv': 6.0},
#    {'time': '2021-06-10 09:00',
#     'temp_c': 24.9,
#     'temp_f': 76.8,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 50,
#     'cloud': 42,
#     'feelslike_c': 25.9,
#     'feelslike_f': 78.6,
#     'windchill_c': 24.9,
#     'windchill_f': 76.8,
#     'heatindex_c': 25.9,
#     'heatindex_f': 78.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.9,
#     'gust_kph': 19.1,
#     'uv': 6.0},
#    {'time': '2021-06-10 10:00',
#     'temp_c': 26.3,
#     'temp_f': 79.3,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 44,
#     'cloud': 37,
#     'feelslike_c': 26.5,
#     'feelslike_f': 79.7,
#     'windchill_c': 26.3,
#     'windchill_f': 79.3,
#     'heatindex_c': 26.5,
#     'heatindex_f': 79.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.6,
#     'gust_kph': 18.7,
#     'uv': 7.0},
#    {'time': '2021-06-10 11:00',
#     'temp_c': 27.6,
#     'temp_f': 81.7,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 37,
#     'cloud': 32,
#     'feelslike_c': 27.2,
#     'feelslike_f': 81.0,
#     'windchill_c': 27.6,
#     'windchill_f': 81.7,
#     'heatindex_c': 27.2,
#     'heatindex_f': 81.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.6,
#     'gust_kph': 18.7,
#     'uv': 7.0},
#    {'time': '2021-06-10 12:00',
#     'temp_c': 28.0,
#     'temp_f': 82.4,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 35,
#     'cloud': 29,
#     'feelslike_c': 27.4,
#     'feelslike_f': 81.3,
#     'windchill_c': 28.0,
#     'windchill_f': 82.4,
#     'heatindex_c': 27.4,
#     'heatindex_f': 81.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.4,
#     'gust_kph': 18.4,
#     'uv': 7.0},
#    {'time': '2021-06-10 13:00',
#     'temp_c': 28.3,
#     'temp_f': 82.9,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 33,
#     'cloud': 27,
#     'feelslike_c': 27.5,
#     'feelslike_f': 81.5,
#     'windchill_c': 28.3,
#     'windchill_f': 82.9,
#     'heatindex_c': 27.5,
#     'heatindex_f': 81.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.4,
#     'gust_kph': 18.4,
#     'uv': 7.0},
#    {'time': '2021-06-10 14:00',
#     'temp_c': 28.7,
#     'temp_f': 83.7,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 31,
#     'cloud': 24,
#     'feelslike_c': 27.7,
#     'feelslike_f': 81.9,
#     'windchill_c': 28.7,
#     'windchill_f': 83.7,
#     'heatindex_c': 27.7,
#     'heatindex_f': 81.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.2,
#     'gust_kph': 18.0,
#     'uv': 7.0},
#    {'time': '2021-06-10 15:00',
#     'temp_c': 28.2,
#     'temp_f': 82.8,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 32,
#     'cloud': 18,
#     'feelslike_c': 27.3,
#     'feelslike_f': 81.1,
#     'windchill_c': 28.2,
#     'windchill_f': 82.8,
#     'heatindex_c': 27.3,
#     'heatindex_f': 81.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 7.0},
#    {'time': '2021-06-10 16:00',
#     'temp_c': 27.6,
#     'temp_f': 81.7,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 32,
#     'cloud': 13,
#     'feelslike_c': 26.8,
#     'feelslike_f': 80.2,
#     'windchill_c': 27.6,
#     'windchill_f': 81.7,
#     'heatindex_c': 26.8,
#     'heatindex_f': 80.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 13.6,
#     'gust_kph': 22.0,
#     'uv': 7.0},
#    {'time': '2021-06-10 17:00',
#     'temp_c': 27.1,
#     'temp_f': 80.8,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 32,
#     'cloud': 7,
#     'feelslike_c': 26.4,
#     'feelslike_f': 79.5,
#     'windchill_c': 27.1,
#     'windchill_f': 80.8,
#     'heatindex_c': 26.4,
#     'heatindex_f': 79.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 14.8,
#     'gust_kph': 23.8,
#     'uv': 7.0},
#    {'time': '2021-06-10 18:00',
#     'temp_c': 26.1,
#     'temp_f': 79.0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 35,
#     'cloud': 7,
#     'feelslike_c': 27.0,
#     'feelslike_f': 80.6,
#     'windchill_c': 26.1,
#     'windchill_f': 79.0,
#     'heatindex_c': 27.0,
#     'heatindex_f': 80.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 15.4,
#     'gust_kph': 24.8,
#     'uv': 7.0},
#    {'time': '2021-06-10 19:00',
#     'temp_c': 25.1,
#     'temp_f': 77.2,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 38,
#     'cloud': 7,
#     'feelslike_c': 27.5,
#     'feelslike_f': 81.5,
#     'windchill_c': 25.1,
#     'windchill_f': 77.2,
#     'heatindex_c': 27.5,
#     'heatindex_f': 81.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 16.1,
#     'gust_kph': 25.9,
#     'uv': 7.0},
#    {'time': '2021-06-10 20:00',
#     'temp_c': 24.1,
#     'temp_f': 75.4,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 41,
#     'cloud': 7,
#     'feelslike_c': 28.1,
#     'feelslike_f': 82.6,
#     'windchill_c': 24.1,
#     'windchill_f': 75.4,
#     'heatindex_c': 28.1,
#     'heatindex_f': 82.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 16.8,
#     'gust_kph': 27.0,
#     'uv': 6.0},
#    {'time': '2021-06-10 21:00',
#     'temp_c': 23.1,
#     'temp_f': 73.6,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 44,
#     'cloud': 6,
#     'feelslike_c': 27.1,
#     'feelslike_f': 80.8,
#     'windchill_c': 23.1,
#     'windchill_f': 73.6,
#     'heatindex_c': 27.1,
#     'heatindex_f': 80.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 15.2,
#     'gust_kph': 24.5,
#     'uv': 1.0},
#    {'time': '2021-06-10 22:00',
#     'temp_c': 22.1,
#     'temp_f': 71.8,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 47,
#     'cloud': 4,
#     'feelslike_c': 26.1,
#     'feelslike_f': 79.0,
#     'windchill_c': 22.1,
#     'windchill_f': 71.8,
#     'heatindex_c': 26.1,
#     'heatindex_f': 79.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 13.9,
#     'gust_kph': 22.3,
#     'uv': 1.0},
#    {'time': '2021-06-10 23:00',
#     'temp_c': 21.1,
#     'temp_f': 70.0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 50,
#     'cloud': 3,
#     'feelslike_c': 21.1,
#     'feelslike_f': 70.0,
#     'windchill_c': 21.1,
#     'windchill_f': 70.0,
#     'heatindex_c': 25.1,
#     'heatindex_f': 77.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 1.0}]},
#  {'date': '2021-06-11',
#   'day': {'maxtemp_c': 21.1,
#    'maxtemp_f': 70.0,
#    'mintemp_c': 17.1,
#    'mintemp_f': 62.8,
#    'avgtemp_c': 19.1,
#    'avgtemp_f': 66.4,
#    'maxwind_kph': 14.4,
#    'totalprecip_mm': 0.1,
#    'totalprecip_in': 0.0,
#    'avghumidity': 61.0,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': '0',
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': '0',
#    'condition': {'text': 'Partly cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#    'uv': 7.0},
#   'astro': {},
#   'hour': [{'time': '2021-06-11 00:00',
#     'temp_c': 19.9,
#     'temp_f': 67.8,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 52,
#     'cloud': 4,
#     'feelslike_c': 19.9,
#     'feelslike_f': 67.8,
#     'windchill_c': 19.9,
#     'windchill_f': 67.8,
#     'heatindex_c': 22.6,
#     'heatindex_f': 72.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 12.1,
#     'gust_kph': 19.4,
#     'uv': 1.0},
#    {'time': '2021-06-11 01:00',
#     'temp_c': 18.8,
#     'temp_f': 65.8,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 55,
#     'cloud': 5,
#     'feelslike_c': 18.8,
#     'feelslike_f': 65.8,
#     'windchill_c': 18.8,
#     'windchill_f': 65.8,
#     'heatindex_c': 20.1,
#     'heatindex_f': 68.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.9,
#     'gust_kph': 19.1,
#     'uv': 1.0},
#    {'time': '2021-06-11 02:00',
#     'temp_c': 17.6,
#     'temp_f': 63.7,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 57,
#     'cloud': 6,
#     'feelslike_c': 17.6,
#     'feelslike_f': 63.7,
#     'windchill_c': 17.6,
#     'windchill_f': 63.7,
#     'heatindex_c': 17.6,
#     'heatindex_f': 63.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.6,
#     'gust_kph': 18.7,
#     'uv': 1.0},
#    {'time': '2021-06-11 03:00',
#     'temp_c': 17.4,
#     'temp_f': 63.3,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 57,
#     'cloud': 7,
#     'feelslike_c': 17.4,
#     'feelslike_f': 63.3,
#     'windchill_c': 17.4,
#     'windchill_f': 63.3,
#     'heatindex_c': 17.4,
#     'heatindex_f': 63.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.4,
#     'gust_kph': 18.4,
#     'uv': 1.0},
#    {'time': '2021-06-11 04:00',
#     'temp_c': 17.1,
#     'temp_f': 62.8,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 57,
#     'cloud': 9,
#     'feelslike_c': 17.1,
#     'feelslike_f': 62.8,
#     'windchill_c': 17.1,
#     'windchill_f': 62.8,
#     'heatindex_c': 17.1,
#     'heatindex_f': 62.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.2,
#     'gust_kph': 18.0,
#     'uv': 1.0},
#    {'time': '2021-06-11 05:00',
#     'temp_c': 16.9,
#     'temp_f': 62.4,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 57,
#     'cloud': 11,
#     'feelslike_c': 16.9,
#     'feelslike_f': 62.4,
#     'windchill_c': 16.9,
#     'windchill_f': 62.4,
#     'heatindex_c': 16.9,
#     'heatindex_f': 62.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.0,
#     'gust_kph': 17.6,
#     'uv': 1.0},
#    {'time': '2021-06-11 06:00',
#     'temp_c': 17.1,
#     'temp_f': 62.8,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 55,
#     'cloud': 15,
#     'feelslike_c': 17.1,
#     'feelslike_f': 62.8,
#     'windchill_c': 17.1,
#     'windchill_f': 62.8,
#     'heatindex_c': 17.1,
#     'heatindex_f': 62.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 10.7,
#     'gust_kph': 17.3,
#     'uv': 5.0},
#    {'time': '2021-06-11 07:00',
#     'temp_c': 17.4,
#     'temp_f': 63.3,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 52,
#     'cloud': 20,
#     'feelslike_c': 17.4,
#     'feelslike_f': 63.3,
#     'windchill_c': 17.4,
#     'windchill_f': 63.3,
#     'heatindex_c': 17.4,
#     'heatindex_f': 63.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 10.5,
#     'gust_kph': 16.9,
#     'uv': 5.0},
#    {'time': '2021-06-11 08:00',
#     'temp_c': 17.6,
#     'temp_f': 63.7,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 50,
#     'cloud': 24,
#     'feelslike_c': 17.6,
#     'feelslike_f': 63.7,
#     'windchill_c': 17.6,
#     'windchill_f': 63.7,
#     'heatindex_c': 17.6,
#     'heatindex_f': 63.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 10.3,
#     'gust_kph': 16.6,
#     'uv': 5.0},
#    {'time': '2021-06-11 09:00',
#     'temp_c': 18.8,
#     'temp_f': 65.8,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 45,
#     'cloud': 31,
#     'feelslike_c': 18.8,
#     'feelslike_f': 65.8,
#     'windchill_c': 18.8,
#     'windchill_f': 65.8,
#     'heatindex_c': 19.6,
#     'heatindex_f': 67.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 10.5,
#     'gust_kph': 16.9,
#     'uv': 5.0},
#    {'time': '2021-06-11 10:00',
#     'temp_c': 20.0,
#     'temp_f': 68.0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 41,
#     'cloud': 38,
#     'feelslike_c': 20.0,
#     'feelslike_f': 68.0,
#     'windchill_c': 20.0,
#     'windchill_f': 68.0,
#     'heatindex_c': 21.6,
#     'heatindex_f': 70.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 10.5,
#     'gust_kph': 16.9,
#     'uv': 6.0},
#    {'time': '2021-06-11 11:00',
#     'temp_c': 21.2,
#     'temp_f': 70.2,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 36,
#     'cloud': 46,
#     'feelslike_c': 21.2,
#     'feelslike_f': 70.2,
#     'windchill_c': 21.2,
#     'windchill_f': 70.2,
#     'heatindex_c': 23.6,
#     'heatindex_f': 74.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 10.7,
#     'gust_kph': 17.3,
#     'uv': 6.0},
#    {'time': '2021-06-11 12:00',
#     'temp_c': 21.2,
#     'temp_f': 70.2,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 38,
#     'cloud': 57,
#     'feelslike_c': 21.2,
#     'feelslike_f': 70.2,
#     'windchill_c': 21.2,
#     'windchill_f': 70.2,
#     'heatindex_c': 23.7,
#     'heatindex_f': 74.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.2,
#     'gust_kph': 18.0,
#     'uv': 5.0},
#    {'time': '2021-06-11 13:00',
#     'temp_c': 21.3,
#     'temp_f': 70.3,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 40,
#     'cloud': 68,
#     'feelslike_c': 21.3,
#     'feelslike_f': 70.3,
#     'windchill_c': 21.3,
#     'windchill_f': 70.3,
#     'heatindex_c': 23.9,
#     'heatindex_f': 75.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.9,
#     'gust_kph': 19.1,
#     'uv': 6.0},
#    {'time': '2021-06-11 14:00',
#     'temp_c': 21.3,
#     'temp_f': 70.3,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 42,
#     'cloud': 79,
#     'feelslike_c': 21.3,
#     'feelslike_f': 70.3,
#     'windchill_c': 21.3,
#     'windchill_f': 70.3,
#     'heatindex_c': 24.0,
#     'heatindex_f': 75.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 5.0},
#    {'time': '2021-06-11 15:00',
#     'temp_c': 21.0,
#     'temp_f': 69.8,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 46,
#     'cloud': 86,
#     'feelslike_c': 21.0,
#     'feelslike_f': 69.8,
#     'windchill_c': 21.0,
#     'windchill_f': 69.8,
#     'heatindex_c': 22.8,
#     'heatindex_f': 73.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 12.1,
#     'gust_kph': 19.4,
#     'uv': 5.0},
#    {'time': '2021-06-11 16:00',
#     'temp_c': 20.6,
#     'temp_f': 69.1,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 51,
#     'cloud': 93,
#     'feelslike_c': 20.6,
#     'feelslike_f': 69.1,
#     'windchill_c': 20.6,
#     'windchill_f': 69.1,
#     'heatindex_c': 21.5,
#     'heatindex_f': 70.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.6,
#     'gust_kph': 18.7,
#     'uv': 5.0},
#    {'time': '2021-06-11 17:00',
#     'temp_c': 20.3,
#     'temp_f': 68.5,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 56,
#     'cloud': 100,
#     'feelslike_c': 20.3,
#     'feelslike_f': 68.5,
#     'windchill_c': 20.3,
#     'windchill_f': 68.5,
#     'heatindex_c': 20.3,
#     'heatindex_f': 68.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.4,
#     'gust_kph': 18.4,
#     'uv': 5.0},
#    {'time': '2021-06-11 18:00',
#     'temp_c': 20.0,
#     'temp_f': 68.0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 59,
#     'cloud': 100,
#     'feelslike_c': 20.0,
#     'feelslike_f': 68.0,
#     'windchill_c': 20.0,
#     'windchill_f': 68.0,
#     'heatindex_c': 20.0,
#     'heatindex_f': 68.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 11.2,
#     'gust_kph': 18.0,
#     'uv': 5.0},
#    {'time': '2021-06-11 19:00',
#     'temp_c': 19.8,
#     'temp_f': 67.6,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 62,
#     'cloud': 100,
#     'feelslike_c': 19.8,
#     'feelslike_f': 67.6,
#     'windchill_c': 19.8,
#     'windchill_f': 67.6,
#     'heatindex_c': 19.8,
#     'heatindex_f': 67.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 10.7,
#     'gust_kph': 17.3,
#     'uv': 4.0},
#    {'time': '2021-06-11 20:00',
#     'temp_c': 19.5,
#     'temp_f': 67.1,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 65,
#     'cloud': 100,
#     'feelslike_c': 19.5,
#     'feelslike_f': 67.1,
#     'windchill_c': 19.5,
#     'windchill_f': 67.1,
#     'heatindex_c': 19.5,
#     'heatindex_f': 67.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 10.5,
#     'gust_kph': 16.9,
#     'uv': 4.0},
#    {'time': '2021-06-11 21:00',
#     'temp_c': 19.3,
#     'temp_f': 66.7,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 67,
#     'cloud': 100,
#     'feelslike_c': 19.3,
#     'feelslike_f': 66.7,
#     'windchill_c': 19.3,
#     'windchill_f': 66.7,
#     'heatindex_c': 19.3,
#     'heatindex_f': 66.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 10.1,
#     'gust_kph': 16.2,
#     'uv': 1.0},
#    {'time': '2021-06-11 22:00',
#     'temp_c': 19.2,
#     'temp_f': 66.6,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 69,
#     'cloud': 99,
#     'feelslike_c': 19.2,
#     'feelslike_f': 66.6,
#     'windchill_c': 19.2,
#     'windchill_f': 66.6,
#     'heatindex_c': 19.2,
#     'heatindex_f': 66.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 9.8,
#     'gust_kph': 15.8,
#     'uv': 1.0},
#    {'time': '2021-06-11 23:00',
#     'temp_c': 19.0,
#     'temp_f': 66.2,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 71,
#     'cloud': 99,
#     'feelslike_c': 19.0,
#     'feelslike_f': 66.2,
#     'windchill_c': 19.0,
#     'windchill_f': 66.2,
#     'heatindex_c': 19.0,
#     'heatindex_f': 66.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 1.0}]},
#  {'date': '2021-06-12',
#   'day': {'maxtemp_c': 24.9,
#    'maxtemp_f': 76.8,
#    'mintemp_c': 17.7,
#    'mintemp_f': 63.9,
#    'avgtemp_c': 20.0,
#    'avgtemp_f': 67.9,
#    'maxwind_kph': 13.0,
#    'totalprecip_mm': 0.1,
#    'totalprecip_in': 0.0,
#    'avghumidity': 72.0,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': '0',
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': '0',
#    'condition': {'text': 'Overcast',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#    'uv': 8.0},
#   'astro': {},
#   'hour': [{'time': '2021-06-12 00:00',
#     'temp_c': 18.9,
#     'temp_f': 66.0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 72,
#     'cloud': 99,
#     'feelslike_c': 18.9,
#     'feelslike_f': 66.0,
#     'windchill_c': 18.9,
#     'windchill_f': 66.0,
#     'heatindex_c': 18.9,
#     'heatindex_f': 66.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 8.9,
#     'gust_kph': 14.4,
#     'uv': 1.0},
#    {'time': '2021-06-12 01:00',
#     'temp_c': 18.7,
#     'temp_f': 65.7,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 73,
#     'cloud': 100,
#     'feelslike_c': 18.7,
#     'feelslike_f': 65.7,
#     'windchill_c': 18.7,
#     'windchill_f': 65.7,
#     'heatindex_c': 18.7,
#     'heatindex_f': 65.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 8.3,
#     'gust_kph': 13.3,
#     'uv': 1.0},
#    {'time': '2021-06-12 02:00',
#     'temp_c': 18.6,
#     'temp_f': 65.5,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 74,
#     'cloud': 100,
#     'feelslike_c': 18.6,
#     'feelslike_f': 65.5,
#     'windchill_c': 18.6,
#     'windchill_f': 65.5,
#     'heatindex_c': 18.6,
#     'heatindex_f': 65.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 7.8,
#     'gust_kph': 12.6,
#     'uv': 1.0},
#    {'time': '2021-06-12 03:00',
#     'temp_c': 18.5,
#     'temp_f': 65.3,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 75,
#     'cloud': 100,
#     'feelslike_c': 18.5,
#     'feelslike_f': 65.3,
#     'windchill_c': 18.5,
#     'windchill_f': 65.3,
#     'heatindex_c': 18.5,
#     'heatindex_f': 65.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 6.5,
#     'gust_kph': 10.4,
#     'uv': 1.0},
#    {'time': '2021-06-12 04:00',
#     'temp_c': 18.4,
#     'temp_f': 65.1,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 76,
#     'cloud': 100,
#     'feelslike_c': 18.4,
#     'feelslike_f': 65.1,
#     'windchill_c': 18.4,
#     'windchill_f': 65.1,
#     'heatindex_c': 18.4,
#     'heatindex_f': 65.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 5.4,
#     'gust_kph': 8.6,
#     'uv': 1.0},
#    {'time': '2021-06-12 05:00',
#     'temp_c': 18.3,
#     'temp_f': 64.9,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 77,
#     'cloud': 100,
#     'feelslike_c': 18.3,
#     'feelslike_f': 64.9,
#     'windchill_c': 18.3,
#     'windchill_f': 64.9,
#     'heatindex_c': 18.3,
#     'heatindex_f': 64.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 4.0,
#     'gust_kph': 6.5,
#     'uv': 1.0},
#    {'time': '2021-06-12 06:00',
#     'temp_c': 18.7,
#     'temp_f': 65.7,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 76,
#     'cloud': 90,
#     'feelslike_c': 18.7,
#     'feelslike_f': 65.7,
#     'windchill_c': 18.7,
#     'windchill_f': 65.7,
#     'heatindex_c': 18.7,
#     'heatindex_f': 65.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 3.8,
#     'gust_kph': 6.1,
#     'uv': 4.0},
#    {'time': '2021-06-12 07:00',
#     'temp_c': 19.0,
#     'temp_f': 66.2,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 74,
#     'cloud': 80,
#     'feelslike_c': 19.0,
#     'feelslike_f': 66.2,
#     'windchill_c': 19.0,
#     'windchill_f': 66.2,
#     'heatindex_c': 19.0,
#     'heatindex_f': 66.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 3.6,
#     'gust_kph': 5.8,
#     'uv': 4.0},
#    {'time': '2021-06-12 08:00',
#     'temp_c': 19.4,
#     'temp_f': 66.9,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 73,
#     'cloud': 69,
#     'feelslike_c': 19.4,
#     'feelslike_f': 66.9,
#     'windchill_c': 19.4,
#     'windchill_f': 66.9,
#     'heatindex_c': 19.4,
#     'heatindex_f': 66.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 3.4,
#     'gust_kph': 5.4,
#     'uv': 4.0},
#    {'time': '2021-06-12 09:00',
#     'temp_c': 20.1,
#     'temp_f': 68.2,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 70,
#     'cloud': 80,
#     'feelslike_c': 20.1,
#     'feelslike_f': 68.2,
#     'windchill_c': 20.1,
#     'windchill_f': 68.2,
#     'heatindex_c': 21.1,
#     'heatindex_f': 70.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 4.5,
#     'gust_kph': 7.2,
#     'uv': 5.0},
#    {'time': '2021-06-12 10:00',
#     'temp_c': 20.8,
#     'temp_f': 69.4,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 67,
#     'cloud': 90,
#     'feelslike_c': 20.8,
#     'feelslike_f': 69.4,
#     'windchill_c': 20.8,
#     'windchill_f': 69.4,
#     'heatindex_c': 22.8,
#     'heatindex_f': 73.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 5.4,
#     'gust_kph': 8.6,
#     'uv': 5.0},
#    {'time': '2021-06-12 11:00',
#     'temp_c': 21.5,
#     'temp_f': 70.7,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 65,
#     'cloud': 100,
#     'feelslike_c': 21.5,
#     'feelslike_f': 70.7,
#     'windchill_c': 21.5,
#     'windchill_f': 70.7,
#     'heatindex_c': 24.5,
#     'heatindex_f': 76.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 6.5,
#     'gust_kph': 10.4,
#     'uv': 5.0},
#    {'time': '2021-06-12 12:00',
#     'temp_c': 21.8,
#     'temp_f': 71.2,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 64,
#     'cloud': 98,
#     'feelslike_c': 21.8,
#     'feelslike_f': 71.2,
#     'windchill_c': 21.8,
#     'windchill_f': 71.2,
#     'heatindex_c': 24.6,
#     'heatindex_f': 76.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 6.7,
#     'gust_kph': 10.8,
#     'uv': 5.0},
#    {'time': '2021-06-12 13:00',
#     'temp_c': 22.2,
#     'temp_f': 72.0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 63,
#     'cloud': 97,
#     'feelslike_c': 24.6,
#     'feelslike_f': 76.3,
#     'windchill_c': 22.2,
#     'windchill_f': 72.0,
#     'heatindex_c': 24.6,
#     'heatindex_f': 76.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 6.9,
#     'gust_kph': 11.2,
#     'uv': 5.0},
#    {'time': '2021-06-12 14:00',
#     'temp_c': 22.5,
#     'temp_f': 72.5,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 62,
#     'cloud': 95,
#     'feelslike_c': 24.7,
#     'feelslike_f': 76.5,
#     'windchill_c': 22.5,
#     'windchill_f': 72.5,
#     'heatindex_c': 24.7,
#     'heatindex_f': 76.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 7.2,
#     'gust_kph': 11.5,
#     'uv': 5.0},
#    {'time': '2021-06-12 15:00',
#     'temp_c': 22.0,
#     'temp_f': 71.6,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 63,
#     'cloud': 90,
#     'feelslike_c': 24.6,
#     'feelslike_f': 76.3,
#     'windchill_c': 22.0,
#     'windchill_f': 71.6,
#     'heatindex_c': 24.6,
#     'heatindex_f': 76.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 7.4,
#     'gust_kph': 11.9,
#     'uv': 5.0},
#    {'time': '2021-06-12 16:00',
#     'temp_c': 21.6,
#     'temp_f': 70.9,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 65,
#     'cloud': 85,
#     'feelslike_c': 21.6,
#     'feelslike_f': 70.9,
#     'windchill_c': 21.6,
#     'windchill_f': 70.9,
#     'heatindex_c': 24.5,
#     'heatindex_f': 76.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 7.8,
#     'gust_kph': 12.6,
#     'uv': 5.0},
#    {'time': '2021-06-12 17:00',
#     'temp_c': 21.1,
#     'temp_f': 70.0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 67,
#     'cloud': 80,
#     'feelslike_c': 21.1,
#     'feelslike_f': 70.0,
#     'windchill_c': 21.1,
#     'windchill_f': 70.0,
#     'heatindex_c': 24.4,
#     'heatindex_f': 75.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 8.1,
#     'gust_kph': 13.0,
#     'uv': 5.0},
#    {'time': '2021-06-12 18:00',
#     'temp_c': 20.7,
#     'temp_f': 69.3,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 68,
#     'cloud': 64,
#     'feelslike_c': 20.7,
#     'feelslike_f': 69.3,
#     'windchill_c': 20.7,
#     'windchill_f': 69.3,
#     'heatindex_c': 22.9,
#     'heatindex_f': 73.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 7.8,
#     'gust_kph': 12.6,
#     'uv': 6.0},
#    {'time': '2021-06-12 19:00',
#     'temp_c': 20.4,
#     'temp_f': 68.7,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 70,
#     'cloud': 49,
#     'feelslike_c': 20.4,
#     'feelslike_f': 68.7,
#     'windchill_c': 20.4,
#     'windchill_f': 68.7,
#     'heatindex_c': 21.5,
#     'heatindex_f': 70.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 7.4,
#     'gust_kph': 11.9,
#     'uv': 5.0},
#    {'time': '2021-06-12 20:00',
#     'temp_c': 20.0,
#     'temp_f': 68.0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 71,
#     'cloud': 33,
#     'feelslike_c': 20.0,
#     'feelslike_f': 68.0,
#     'windchill_c': 20.0,
#     'windchill_f': 68.0,
#     'heatindex_c': 20.0,
#     'heatindex_f': 68.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 7.2,
#     'gust_kph': 11.5,
#     'uv': 6.0},
#    {'time': '2021-06-12 21:00',
#     'temp_c': 19.5,
#     'temp_f': 67.1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 73,
#     'cloud': 31,
#     'feelslike_c': 19.5,
#     'feelslike_f': 67.1,
#     'windchill_c': 19.5,
#     'windchill_f': 67.1,
#     'heatindex_c': 19.5,
#     'heatindex_f': 67.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 7.4,
#     'gust_kph': 11.9,
#     'uv': 1.0},
#    {'time': '2021-06-12 22:00',
#     'temp_c': 19.1,
#     'temp_f': 66.4,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 75,
#     'cloud': 30,
#     'feelslike_c': 19.1,
#     'feelslike_f': 66.4,
#     'windchill_c': 19.1,
#     'windchill_f': 66.4,
#     'heatindex_c': 19.1,
#     'heatindex_f': 66.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 7.6,
#     'gust_kph': 12.2,
#     'uv': 1.0},
#    {'time': '2021-06-12 23:00',
#     'temp_c': 18.6,
#     'temp_f': 65.5,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png'},
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 77,
#     'cloud': 28,
#     'feelslike_c': 18.6,
#     'feelslike_f': 65.5,
#     'windchill_c': 18.6,
#     'windchill_f': 65.5,
#     'heatindex_c': 18.6,
#     'heatindex_f': 65.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'gust_mph': 7.8,
#     'gust_kph': 12.6,
#     'uv': 1.0}]}]

# %%
columns = ['time', 'temp_f', 'feelslike_f', 'chance_of_rain', 'chance_of_snow']
hourly_forecast = pd.DataFrame(data['forecast']['forecastday'][0]['hour'])[columns]
hourly_forecast['time'] = hourly_forecast['time'].map(lambda x: x[-5:-3])
hourly_forecast = hourly_forecast.astype({'chance_of_rain': np.float,
                                          'chance_of_snow': np.float})
sns.set_theme()
fig, ax = plt.subplots(figsize = (10,5))
ax.plot(hourly_forecast['time'],
        hourly_forecast['temp_f']
       )
ax.plot(hourly_forecast['time'],
        hourly_forecast['feelslike_f']
       )

ax.plot(hourly_forecast['time'],
        hourly_forecast['chance_of_rain'],
        '--',
        color = 'c'
       )
ax.plot(hourly_forecast['time'],
        hourly_forecast['chance_of_snow'],
        '-.',
        color = 'slategrey'
       )


ax.set_yticks(list(range(0,100,10)))
ax.legend(['Actual Temp', 'Feels Like', 'Chance of Rain', 'Chance of Snow'])
plt.suptitle(f'Hourly Forecast for {data["forecast"]["forecastday"][0]["date"]}');

# %%
    sns.set_theme()
    fig, ax = plt.subplots(2,1, figsize = (20,10), sharex = True)

    ax[0].plot(hourly_forecast['time'],
               hourly_forecast['temp_f']
               )
    ax[0].plot(hourly_forecast['time'],
               hourly_forecast['feelslike_f']
               )

    ax[1].plot(hourly_forecast['time'],
               hourly_forecast['chance_of_rain']
               )
    ax[1].plot(hourly_forecast['time'],
               hourly_forecast['chance_of_snow']
               )

    ax[0].set_yticks(list(range(0,100,10)))
    ax[1].set_yticks(list(range(0,100,10)))
    ax[0].legend(['Actual Temp', 'Feels Like'])
    ax[1].legend(['Chance of Rain', 'Chance of Snow'])
    plt.suptitle(f'Hourly Forecast for {data["forecast"]["forecastday"][0]["date"]}')

# %%
with open('.secrets/APIs.json') as f:
    APIs = json.load(f)
API_KEY = APIs['weather']

#Format url with key, optional zipcode argument
url = 'http://api.weatherapi.com/v1/forecast.json?key='+API_KEY+'&q=07024&days=3&aqi=no'
response = requests.get(url)

#Return response as json
data = response.json()
